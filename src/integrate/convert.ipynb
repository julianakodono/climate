# %% [markdown]
# # Conversão
#
# NetCDF para CSV
#
# * Requer `CO2_1deg_month_1850-2013.nc` em `.\data`
# * Arquvio de saída em `.\out\co2_daa.csv`

# %%
import xarray as xr

# %%
nc = xr.open_dataset('./data/CO2_1deg_month_1850-2013.nc')
nc
# Out:
# <xarray.Dataset>
# Dimensions:    (LonDim: 360, LatDim: 180, Times: 1968)
# Coordinates:
#   * Times      (Times) datetime64[ns] 1850-01-01 1850-02-01 ... 2013-12-01
# Dimensions without coordinates: LonDim, LatDim
# Data variables:
#     Longitude  (LonDim) float64 ...
#     Latitude   (LatDim) float64 ...
#     value      (Times, LatDim, LonDim) float64 ...

# %% [markdown]
# A conversão de fato, sua execução pode levar cerca de 15 minutos e o arquivo de saída possuirá por volta de 4.4 GB.

# %%
nc.value.to_dataframe().to_csv('./out/co2_data.csv')
